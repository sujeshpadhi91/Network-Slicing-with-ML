# %% [markdown]
# # **Import Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# # **Load Dataset**

# %%
# data = pd.read_csv('/content/drive/MyDrive/Dataset/random_seed_results_custom.csv')
data = pd.read_csv('/content/drive/MyDrive/Dataset/random_seed_results.csv')
data
# Out:
#     Iteration No.  Under-sampling  Data-split  Modeling  Accuracy  Precision  \
# 0               1              43          43        43  0.944995   0.949137
# 1               2              43          43        42  0.944995   0.949137
# 2               3              43          43        40  0.944995   0.949137
# 3               4              43          43        38  0.944995   0.949137
# 4               5              43          42        42  0.927412   0.934515
# 5               6              43          42        41  0.927412   0.934515
# 6               7              43          42        39  0.927412   0.934515
# 7               8              43          42        38  0.927412   0.934515
# 8               9              43          42        37  0.927412   0.934515
# 9              10              43          41        43  0.936880   0.942494
# 10             11              43          41        42  0.936880   0.942494
# 11             12              43          41        39  0.825068   0.844665
# 12             13              43          41        38  0.825068   0.844665
# 13             14              43          40        43  0.932822   0.938957
# 14             15              43          40        42  0.932822   0.938957
# 15             16              42          42        42  0.927412   0.934515
# 16             17              42          42        41  0.821461   0.841102
# 17             18              42          42        39  0.821461   0.841102
# 18             19              42          42        37  0.927412   0.934515
# 19             20              42          41        41  0.922453   0.930647
# 20             21              42          40        42  0.933273   0.939453
# 21             22              42          40        40  0.810189   0.832921
# 22             23              42          40        39  0.933273   0.939453
# 23             24              42          40        37  0.810189   0.832921
# 24             25              41          42        40  0.932822   0.938919
# 25             26              41          42        39  0.832732   0.850599
# 26             27              41          42        38  0.832732   0.850599
# 27             28              41          42        37  0.932822   0.938919
# 28             29              41          41        42  0.927412   0.934740
# 29             30              41          41        41  0.894049   0.909728
# 30             31              41          41        40  0.927412   0.934740
# 31             32              41          41        39  0.927412   0.934740
# 32             33              41          41        38  0.927412   0.934740
# 33             34              41          40        42  0.928314   0.935355
# 34             35              41          40        40  0.810640   0.833918
# 35             35              41          40        38  0.928314   0.935355
# 36             35              41          40        37  0.928314   0.935355
# 37             35              40          42        42  0.931921   0.938280
# 38             35              40          42        41  0.931921   0.938280
# 39             35              40          42        40  0.931921   0.938280
# 40             35              40          42        39  0.931921   0.938280
# 41             35              40          42        38  0.931921   0.938280
# 42             35              40          42        37  0.931921   0.938280
# 43             35              40          41        41  0.927412   0.934526
# 44             35              40          41        40  0.927412   0.934526
# 45             35              40          40        42  0.937782   0.942943
# 46             35              40          40        41  0.813345   0.834334
# 47             35              40          40        38  0.813345   0.834334
# 48             35              40          40        37  0.937782   0.942943
#
#       Recall  F1-score
# 0   0.944995  0.943475
# 1   0.944995  0.943475
# 2   0.944995  0.943475
# 3   0.944995  0.943475
# 4   0.927412  0.924795
# 5   0.927412  0.924795
# 6   0.927412  0.924795
# 7   0.927412  0.924795
# 8   0.927412  0.924795
# 9   0.936880  0.935019
# 10  0.936880  0.935019
# 11  0.825068  0.823257
# 12  0.825068  0.823257
# 13  0.932822  0.930583
# 14  0.932822  0.930583
# 15  0.927412  0.924788
# 16  0.821461  0.819753
# 17  0.821461  0.819753
# 18  0.927412  0.924788
# 19  0.922453  0.919617
# 20  0.933273  0.931336
# 21  0.810189  0.808648
# 22  0.933273  0.931336
# 23  0.810189  0.808648
# 24  0.932822  0.930500
# 25  0.832732  0.830765
# 26  0.832732  0.830765
# 27  0.932822  0.930500
# 28  0.927412  0.925171
# 29  0.894049  0.888916
# 30  0.927412  0.925171
# 31  0.927412  0.925171
# 32  0.927412  0.925171
# 33  0.928314  0.925953
# 34  0.810640  0.808878
# 35  0.928314  0.925953
# 36  0.928314  0.925953
# 37  0.931921  0.929790
# 38  0.931921  0.929790
# 39  0.931921  0.929790
# 40  0.931921  0.929790
# 41  0.931921  0.929790
# 42  0.931921  0.929790
# 43  0.927412  0.924825
# 44  0.927412  0.924825
# 45  0.937782  0.935677
# 46  0.813345  0.810183
# 47  0.813345  0.810183
# 48  0.937782  0.935677

# %% [markdown]
# # 95% Confidence Interval

# %%
def CI95(data):
  # Calculate sample mean and sample standard deviation
  sample_mean = np.mean(data)
  sample_std = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation
  # Calculate the critical value (z) for a 95% confidence level
  # z_critical_95_direct = 1.96 # Direct value
  z_critical_95 = stats.norm.ppf(0.975)  # For a two-tailed test
  # print("Zcritical (95)): ", z_critical_95)
  # Calculate margin of error (ME)
  ME_95 = z_critical_95 * (sample_std / np.sqrt(len(data)))
  # print("Margin of Error (95): ", ME_95)
  # Calculate the confidence interval
  lower_limit_95 = sample_mean - ME_95
  upper_limit_95 = sample_mean + ME_95
  # print("Lower Limit (95): ", lower_limit_95)
  # print("Upper Limit (95): ", upper_limit_95)
  # Print results
  # print("Sample Mean (𝑥̄):", sample_mean)
  # print("Sample Standard Deviation (s):", sample_std)
  # print("Margin of Error (ME):", ME_95)
  # print("95% Confidence Interval: [{:.3f}, {:.3f}]".format(lower_limit_95, upper_limit_95))
  return (lower_limit_95, upper_limit_95)

# %% [markdown]
# # 99% Confidence Interval

# %%
def CI99(data):
  # Calculate sample mean and sample standard deviation
  sample_mean = np.mean(data)
  sample_std = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation
  # Calculate the critical value (z) for a 99% confidence level
  # z_critical_99_direct = 2.576 # Direct value
  z_critical_99 = stats.norm.ppf(0.995)  # For a two-tailed test
  # print("Zcritical (99)): ", z_critical_99)
  # Calculate margin of error (ME) for 99% confidence level
  ME_99 = z_critical_99 * (sample_std / np.sqrt(len(data)))
  # print("Margin of Error (99): ", ME_99)
  # Calculate the confidence interval for 99% confidence level
  lower_limit_99 = sample_mean - ME_99
  upper_limit_99 = sample_mean + ME_99
  # print("Lower Limit (99): ", lower_limit_99)
  # print("Upper Limit (99): ", upper_limit_99)
  # Print results
  # print("Sample Mean (𝑥̄):", sample_mean)
  # print("Sample Standard Deviation (s):", sample_std)
  # print("Margin of Error (ME):", ME_99)
  # print("99% Confidence Interval: [{:.3f}, {:.3f}]".format(lower_limit_99, upper_limit_99))
  return (lower_limit_99, upper_limit_99)

# %% [markdown]
# # **Main**

# %% [markdown]
# ## **Accuracy**

# %%
accuracy_data = data['Accuracy']
accuracy_data
# Out:
# 0     0.963330
# 1     0.963330
# 2     0.963330
# 3     0.963330
# 4     0.951608
# 5     0.951608
# 6     0.951608
# 7     0.951608
# 8     0.951608
# 9     0.957920
# 10    0.957920
# 11    0.883378
# 12    0.883378
# 13    0.955215
# 14    0.955215
# 15    0.951608
# 16    0.880974
# 17    0.880974
# 18    0.951608
# 19    0.948302
# 20    0.955515
# 21    0.873460
# 22    0.955515
# 23    0.873460
# 24    0.955215
# 25    0.888488
# 26    0.888488
# 27    0.955215
# 28    0.951608
# 29    0.929366
# 30    0.951608
# 31    0.951608
# 32    0.951608
# 33    0.952209
# 34    0.873760
# 35    0.952209
# 36    0.952209
# 37    0.954614
# 38    0.954614
# 39    0.954614
# 40    0.954614
# 41    0.954614
# 42    0.954614
# 43    0.951608
# 44    0.951608
# 45    0.958521
# 46    0.875564
# 47    0.875564
# 48    0.958521
# Name: Accuracy, dtype: float64

# %%
accuracy_95_CI = CI95(accuracy_data)
accuracy_99_CI = CI99(accuracy_data)
print("95% Confidence Interval:", accuracy_95_CI)
print("99% Confidence Interval:", accuracy_99_CI)
# Out:
# 95% Confidence Interval: (0.9284193866607537, 0.9462118003496682)
# 99% Confidence Interval: (0.925623995873246, 0.949007191137176)

# %% [markdown]
# ## **Precision**

# %%
precision_data = data['Precision']
precision_data
# Out:
# 0     0.944995
# 1     0.944995
# 2     0.944995
# 3     0.944995
# 4     0.927412
# 5     0.927412
# 6     0.927412
# 7     0.927412
# 8     0.927412
# 9     0.936880
# 10    0.936880
# 11    0.825068
# 12    0.825068
# 13    0.932822
# 14    0.932822
# 15    0.927412
# 16    0.821461
# 17    0.821461
# 18    0.927412
# 19    0.922453
# 20    0.933273
# 21    0.810189
# 22    0.933273
# 23    0.810189
# 24    0.932822
# 25    0.832732
# 26    0.832732
# 27    0.932822
# 28    0.927412
# 29    0.894049
# 30    0.927412
# 31    0.927412
# 32    0.927412
# 33    0.928314
# 34    0.810640
# 35    0.928314
# 36    0.928314
# 37    0.931921
# 38    0.931921
# 39    0.931921
# 40    0.931921
# 41    0.931921
# 42    0.931921
# 43    0.927412
# 44    0.927412
# 45    0.937782
# 46    0.813345
# 47    0.813345
# 48    0.937782
# Name: Precision, dtype: float64

# %%
precision_95_CI = CI95(precision_data)
precision_99_CI = CI99(precision_data)
print("95% Confidence Interval:", precision_95_CI)
print("99% Confidence Interval:", precision_99_CI)
# Out:
# 95% Confidence Interval: (0.8926290799911306, 0.9193177005245025)
# 99% Confidence Interval: (0.8884359938098689, 0.9235107867057641)

# %% [markdown]
# ## **Recall**

# %%
recall_data = data['Recall']
recall_data
# Out:
# 0     0.944995
# 1     0.944995
# 2     0.944995
# 3     0.944995
# 4     0.927412
# 5     0.927412
# 6     0.927412
# 7     0.927412
# 8     0.927412
# 9     0.936880
# 10    0.936880
# 11    0.825068
# 12    0.825068
# 13    0.932822
# 14    0.932822
# 15    0.927412
# 16    0.821461
# 17    0.821461
# 18    0.927412
# 19    0.922453
# 20    0.933273
# 21    0.810189
# 22    0.933273
# 23    0.810189
# 24    0.932822
# 25    0.832732
# 26    0.832732
# 27    0.932822
# 28    0.927412
# 29    0.894049
# 30    0.927412
# 31    0.927412
# 32    0.927412
# 33    0.928314
# 34    0.810640
# 35    0.928314
# 36    0.928314
# 37    0.931921
# 38    0.931921
# 39    0.931921
# 40    0.931921
# 41    0.931921
# 42    0.931921
# 43    0.927412
# 44    0.927412
# 45    0.937782
# 46    0.813345
# 47    0.813345
# 48    0.937782
# Name: Recall, dtype: float64

# %%
recall_95_CI = CI95(recall_data)
recall_99_CI = CI99(recall_data)
print("95% Confidence Interval:", recall_95_CI)
print("99% Confidence Interval:", recall_99_CI)
# Out:
# 95% Confidence Interval: (0.8926290799911306, 0.9193177005245025)
# 99% Confidence Interval: (0.8884359938098689, 0.9235107867057641)

# %% [markdown]
# ## **F1-score**

# %%
f1score_data = data['F1-score']
f1score_data
# Out:
# 0     0.944995
# 1     0.944995
# 2     0.944995
# 3     0.944995
# 4     0.927412
# 5     0.927412
# 6     0.927412
# 7     0.927412
# 8     0.927412
# 9     0.936880
# 10    0.936880
# 11    0.825068
# 12    0.825068
# 13    0.932822
# 14    0.932822
# 15    0.927412
# 16    0.821461
# 17    0.821461
# 18    0.927412
# 19    0.922453
# 20    0.933273
# 21    0.810189
# 22    0.933273
# 23    0.810189
# 24    0.932822
# 25    0.832732
# 26    0.832732
# 27    0.932822
# 28    0.927412
# 29    0.894049
# 30    0.927412
# 31    0.927412
# 32    0.927412
# 33    0.928314
# 34    0.810640
# 35    0.928314
# 36    0.928314
# 37    0.931921
# 38    0.931921
# 39    0.931921
# 40    0.931921
# 41    0.931921
# 42    0.931921
# 43    0.927412
# 44    0.927412
# 45    0.937782
# 46    0.813345
# 47    0.813345
# 48    0.937782
# Name: F1-score, dtype: float64

# %%
f1score_95_CI = CI95(f1score_data)
f1score_99_CI = CI99(f1score_data)
print("95% Confidence Interval:", f1score_95_CI)
print("99% Confidence Interval:", f1score_99_CI)
# Out:
# 95% Confidence Interval: (0.8926290799911306, 0.9193177005245025)
# 99% Confidence Interval: (0.8884359938098689, 0.9235107867057641)

# %% [markdown]
# # **SYNC NOTEBOOKS**

# %%
# %cp '/content/drive/MyDrive/Colab Notebooks/Exp9 - Confidence_Interval.ipynb' '/content/drive/MyDrive/Network_Slicing_with_ML_repo/Network-Slicing-with-ML/Notebooks/'
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/Exp9 - Confidence_Interval.ipynb': No such file or directory
